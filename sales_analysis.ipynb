# %% [markdown]
# <a href="https://colab.research.google.com/github/gknoetze36-source/sales---Analysis/blob/main/sales_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sales_analysis.ipynb
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2795794800.py in <cell line: 0>()
# ----> 1 sales_analysis.ipynb
#       2
#       3 import numpy as np #
#       4 import pandas as pd #
#       5
#
# NameError: name 'sales_analysis' is not defined

# %%
import numpy as np #
import pandas as pd #

import os
for dirname, _, filenames in os.walk('/kaggle/input') :
  for filename in filenames :
    print (os.path.joi(dirname, filename))

# %%
df = pd. read_csv("/kaggle/input/cafe-sales-dirty-data-for-cleaning-training/dirty_cafe_sales.csv")
df.info()

# %%
df.head()

# %%
df = df.replace("UNKNOWN , ERROR, np.nan")

# %%
cols = ['quantity', 'price per unit', 'Total Spent']
df = df[df[df[cols].isnull().sum(axis=1) <= 1]]

# %%
df['Quantity'] = pd.to_numeric(df['Quantity'], errors='coerce')
df['Price Per Unit'] = pd.to_numeric(df['Price Per Unit'], errors='coerce')
df['Total Spent'] = pd.to_numeric(df['Total Spent'], errors='coerce')

# %%
def infer_null(rows, formula):
    '''Applies a formula to null values to infer the result'''
    return np.where(
        rows.isnull(),
        formula,
        rows
    )

# Quantity = Total Spent / Price Per Unit
df['Quantity'] = infer_null(
    rows=df['Quantity'],
    formula=df['Total Spent'] / df['Price Per Unit']
).astype(int)

# Price Per Unit = Total Spent / Quantity
df['Price Per Unit'] = infer_null(
    rows=df['Price Per Unit'],
    formula=df['Total Spent'] / df['Quantity']
).astype(float)

# Total Spent = Quantity * Price Per Unit
df['Total Spent'] = infer_null(
    rows=df['Total Spent'],
    formula=df['Quantity'] * df['Price Per Unit']
).astype(float)

# %%
df = df.dropna(subset=['Transaction Date'])
df['Transaction Date'] = pd.to_datetime(df['Transaction Date'], errors='coerce')

# %%
df = df.replace(np.nan, 'Unknown')

# %%
df['Item'] = df['Item'].astype('category')
df['Payment Method'] = df['Payment Method'].astype('category')
df['Location'] = df['Location'].astype('category')

# %%
assert sum(df.isnull().sum()) == 0

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3771845804.py in <cell line: 0>()
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %%
df.head()
